# %% [markdown]
# https://www.hani.co.kr/arti/culture/entertainment/816895.html

# %%
# !pip install --upgrade pip
#!pip install gensim
# !pip3 install newspaper3k
# !pip install kiwipiepy

# %%
from newspaper import Article
import re

def crawling(url):
    # url = input('url을 입력하세요')
    article = Article(url,laguage='ko')
    article.download()
    article.parse()
    title = article.title
    text = article.text
    text = '.'.join(article.text.split('.')[:-2:])
    #text = ''.join(text.split('기자) ')[1]) # split 할 경우
    # text = re.search(r'기자\)\s*(.*)', text)[1] # 정규표현식으로 할경우
    return title , text

import pandas as pd
url = input("검사를 위한 URL을 입력해주세요: ")
title, text = crawling(url)
data = {'text': [text]}
df = pd.DataFrame(data)

from kiwipiepy import Kiwi
kiwi = Kiwi()
def extract_nouns(text):
    result = kiwi.tokenize(text)
    for token in result:
        if token.tag in ['NNG', 'NNP']:
            yield token.form

from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(tokenizer=extract_nouns, min_df=1)
dtm = cv.fit_transform(df.text)

word_count = pd.DataFrame({
    'word': cv.get_feature_names_out(),
    'count': dtm.sum(axis=0).flat
})


top5_keywords = word_count.sort_values('count', ascending=False).head(5)
for i in  range(5):
  word, count = top5_keywords.iloc[i]
  print("{}의 빈도수는 {}".format(word, count))
# Out:
# 검사를 위한 URL을 입력해주세요: ttps://www.xportsnews.com/article/1776390
# ---------------------------------------------------------------------------
# ArticleException                          Traceback (most recent call last)
# <ipython-input-2-9f41c3dda021> in <cell line: 18>()
#      16 import pandas as pd
#      17 url = input("검사를 위한 URL을 입력해주세요: ")
# ---> 18 title, text = crawling(url)
#      19 data = {'text': [text]}
#      20 df = pd.DataFrame(data)
#
# <ipython-input-2-9f41c3dda021> in crawling(url)
#       6     article = Article(url,laguage='ko')
#       7     article.download()
# ----> 8     article.parse()
#       9     title = article.title
#      10     text = article.text
#
# /usr/local/lib/python3.10/dist-packages/newspaper/article.py in parse(self)
#     189
#     190     def parse(self):
# --> 191         self.throw_if_not_downloaded_verbose()
#     192
#     193         self.doc = self.config.get_parser().fromstring(self.html)
#
# /usr/local/lib/python3.10/dist-packages/newspaper/article.py in throw_if_not_downloaded_verbose(self)
#     529             raise ArticleException('You must `download()` an article first!')
#     530         elif self.download_state == ArticleDownloadState.FAILED_RESPONSE:
# --> 531             raise ArticleException('Article `download()` failed with %s on URL %s' %
#     532                   (self.download_exception_msg, self.url))
#     533
#
# ArticleException: Article `download()` failed with No connection adapters were found for 'ttps://www.xportsnews.com/article/1776390' on URL ttps://www.xportsnews.com/article/1776390
